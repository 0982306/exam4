# %%
// Components will always contain a Nav.vue and other things that structure the website. For example, a pet card that is a blueprint for pet data

// Components will always need an export default inside script tags at the top. Depending on the component, the export default will only need props.
export default {
    data() {
        return {

        }
    }
}

// Along with a template to display html
<template>
    <p>This is an example</p>
</template>

# %%
// Routes can be tricky. Good thing past me is prepared for this!
// Firstly, go to index.js delete everything EXCEPT:
import { createRouter, createWebHistory } from 'vue-router'
export default router

// Everything else, we don't care. We're going to write out own shit.


// The second thing that needs to be done is to import the pages from the views folder.
// Side note: The App.vue is everything put together. Home.vue and others are individual pages in the App. 

// Anyway, you need to import the vues from views. For example, to import the home page, it would look like this:
import Home from '../views.Home.vue'


// After you import the vues, you create the routes itself. It will be an array called 'routes' (pretty straightfoward, right?). The array will contain a 'path' and a 'component'.
const routes = [
    { path: '/', component: Home }
]

// Lastly, you create the router which is the hard part because it contains stuff I will NOT remember.
const router = createRouter({
    history: createWebHistory(import.meta.env.BASE_URL), routes
})

# %%
// Like I said earlier, Home.vue is just a page of the App.vue. All it contains is some html to make it full of information
<template>
    <h1>This is an example</h1>
</template>

# %%
// Time for the App.vue. The App is the whole project. Basically, it the the index.html but for a vue project. It needs a few things in the script tag
// Importing the Navigation
import Nav from './components/Nav.vue'

// The export default
export default {
    // needs the Nav component
    components: { Nav },
    data(){
        return {
            // data in here if something needs to be returned
            // for example, pet information
        }
    },
    methods: {
        // if any
    }
}

// The template part of the App is much more simpler. If you have multiple components, you will need to put them in a <div> tag because they can only be seen as one. Basically you just need the <Nav> in there
